# %% [markdown]
# ## Week 6: Dynamic Programming
#
# Presentado por: David Rojas Carranza - Grupo 19
#
# ###6-1: Maximun Amount of Gold

# %%
# %%writefile max_gold.py
import numpy

W, n = list(map(int, input().split()))
items = list(map(int, input().split()))

value = numpy.zeros((W+1, n+1))
for i in range(1,W+1):
  for j in range(1,n+1):
    value[i][j] = value[i][j-1]
    if items[j-1]<=i:
      temp = value[i-items[j-1]][j-1] + items[j-1]
      if temp > value[i][j]:
        value[i][j] = temp

print(int(value[W][n]))
# Out:
# Overwriting max_gold.py

# %%
# !python max_gold.py
# Out:
# 10 3
# 1 4 8
# 9

# %% [markdown]
# ##6-2: Partitioning souvenirs

# %%
# %%writefile partitioning.py
import numpy

n = int(input())
item_weights = [int(i) for i in input().split()]
total_weight = sum(item_weights)

if n<3: 
    print('0')
elif total_weight%3 != 0: 
    print('0')
else:
    W = total_weight//3

    count = 0 
    value = numpy.zeros((W+1, n+1))
    for i in range(1, W+1):
      for j in range(1, n+1):
          value[i][j] = value[i][j-1]
          if item_weights[j-1]<=i:
            temp = value[i-item_weights[j-1]][j-1] + item_weights[j-1]
            if temp > value[i][j]:
              value[i][j] = temp
            if value[i][j] == W: count += 1
        
    if count < 3: 
      print('0')
    else: 
      print('1')
# Out:
# Overwriting partitioning.py

# %%
# !python partitioning.py
# Out:
# 4
# 3 3 3 3
# 0

# %%
# !python partitioning.py
# Out:
# 1
# 40
# 0

# %%
# !python partitioning.py
# Out:
# 11
# 17 59 34 57 17 23 67 1 18 2 59
# 1

# %%
# !python partitioning.py
# Out:
# 13
# 1 2 3 4 5 5 7 7 8 10 12 19 25
# 1

# %% [markdown]
# ##Cousera passed
#
# ![Week 6 ss.png](data:image/png;base64,...)
